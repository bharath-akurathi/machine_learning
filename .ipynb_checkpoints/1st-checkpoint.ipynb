# %%
import math
from collections import Counter

# Taking input from the user
data = list(map(float, input("Enter numbers separated by space: ").split()))

n = len(data)
# Out:
# Enter numbers separated by space:  1 2 2 3 3 4 4 4 5 6

# %%
# Mean
mean = sum(data) / n
mean
# Out:
# 3.4

# %%
#Median
data.sort()

# %%
if n % 2 == 0:
    median = (data[n//2 - 1] + data[n//2]) / 2
else:
    median = data[n//2]

median
# Out:
# 3.5

# %%
#Mode 
frequency = Counter(data)
frequency
# Out:
# Counter({4.0: 3, 2.0: 2, 3.0: 2, 1.0: 1, 5.0: 1, 6.0: 1})

# %%
max_freq=max(frequency.values())
max_freq
# Out:
# 3

# %%
for key, value in frequency.items() :
    if value == max_freq :
        mode = key

mode
# Out:
# 4.0

# %%
variance = sum((x - mean) ** 2 for x in data) / n
variance
# Out:
# 2.04

# %%
std_deviation = math.sqrt(variance)
std_deviation
# Out:
# 1.42828568570857

# %%
import math
from collections import Counter

# Taking input from the user
data = list(map(float, input("Enter numbers separated by space: ").split()))

n = len(data)

# Mean
mean = sum(data) / n

# Median
data.sort()
if n % 2 == 0:
    median = (data[n//2 - 1] + data[n//2]) / 2
else:
    median = data[n//2]

# Mode
frequency = Counter(data)
max_freq = max(frequency.values())
mode = [key for key, value in frequency.items() if value == max_freq]

# Variance = (sigma(x-U)**2)/n
variance = sum((x - mean) ** 2 for x in data) / n

# Standard Deviation
std_deviation = math.sqrt(variance)
# 
# Displaying results
print("\nMeasures of Central Tendency:")
print("Mean =", mean)
print("Median =", median)
print("Mode =", mode)

print("\nMeasures of Dispersion:")
print("Variance =", variance)
print("Standard Deviation =", std_deviation)
# Out:
# Enter numbers separated by space:  1 2 2 3 3 4 4 4 5 6
# Measures of Central Tendency:
# Mean = 3.4
# Median = 3.5
# Mode = [4.0]
#
# Measures of Dispersion:
# Variance = 2.04
# Standard Deviation = 1.42828568570857
