# %%
import math

print("Square root:", math.sqrt(25))
print("Power:", math.pow(2, 3))
print("Factorial:", math.factorial(5))
print("Log:", math.log(10))
print("Log:", math.log(math.e))
# Out:
# Square root: 5.0
# Power: 8.0
# Factorial: 120
# Log: 2.302585092994046
# Log: 1.0

# %%
print(math.e)
# Out:
# 2.718281828459045

# %%
# math.inf	Returns a floating-point positive infinity
# math.nan	Returns a floating-point NaN (Not a Number) value
# math.pi	Returns PI (3.1415...)
# math.tau  Returns tau (6.2831...)

# %%
# statistics.harmonic_mean()	Calculates the harmonic mean (central location) of the given data
# statistics.mean()	Calculates the mean (average) of the given data
# statistics.median()	Calculates the median (middle value) of the given data
# statistics.median_grouped()	Calculates the median of grouped continuous data
# statistics.median_high()	Calculates the high median of the given data
# statistics.median_low()	Calculates the low median of the given data
# statistics.mode()	Calculates the mode (central tendency) of the given numeric or nominal data
# statistics.pstdev()	Calculates the standard deviation from an entire population
# statistics.stdev()	Calculates the standard deviation from a sample of data
# statistics.pvariance()	Calculates the variance of an entire population
# statistics.variance()	Calculates the variance from a sample of data

# %%
data = [1,2,3,4,5,6,6,4,3,2,1,5,5,5]

# %%
import statistics
print("Mean:", statistics.mean(data))
print("Median:", statistics.median(data))
print("Mode:", statistics.mode(data))
print("Variance:", statistics.variance(data))
print("Standard Deviation:", statistics.stdev(data))
# Out:
# Mean: 3.7142857142857144
# Median: 4.0
# Mode: 5
# Variance: 2.989010989010989
# Standard Deviation: 1.7288756430151329

# %%
# !pip install numpy
# Out:
# Collecting numpy
#   Downloading numpy-2.4.1-cp313-cp313-macosx_14_0_arm64.whl.metadata (6.6 kB)
# Downloading numpy-2.4.1-cp313-cp313-macosx_14_0_arm64.whl (5.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 623.6 kB/s  0:00:082.4 kB/s eta 0:00:01
# Installing collected packages: numpy
# Successfully installed numpy-2.4.1

# %%
import numpy as np

arr = np.array([1, 2, 3, 4, 5])

print(arr)
# Out:
# [1 2 3 4 5]

# %%
print("Mean:", np.mean(arr))
print("Median:", np.median(arr))
# print("Mode:", np.mode(arr)) --> mode is not present
print("Standard Deviation:", np.std(arr))
print("Sum:", np.sum(arr))
# Out:
# Mean: 3.0
# Median: 3.0
# Standard Deviation: 1.4142135623730951
# Sum: 15

# %%
# SciPy is built on NumPy and is used for advanced scientific and technical computing.

# %%
# !pip install scipy
# Out:
# Collecting scipy
#   Downloading scipy-1.17.0-cp313-cp313-macosx_14_0_arm64.whl.metadata (62 kB)
# Requirement already satisfied: numpy<2.7,>=1.26.4 in /opt/miniconda3/lib/python3.13/site-packages (from scipy) (2.4.1)
# Downloading scipy-1.17.0-cp313-cp313-macosx_14_0_arm64.whl (20.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.1/20.1 MB 902.1 kB/s  0:00:22 eta 0:00:010:00:01
# Installing collected packages: scipy
# Successfully installed scipy-1.17.0

# %%
from scipy import stats

data = [5, 5 ,5 ,10, 15, 20, 25]

print("Mean:", stats.tmean(data))
print("Median:", stats.scoreatpercentile(data, 50))
print("Mode:", stats.mode(data))
# Out:
# Mean: 12.142857142857142
# Median: 10.0
# Mode: ModeResult(mode=np.int64(5), count=np.int64(3))

# %%
# 50 represents the 50th percentile
# The 50th percentile is the Median

# %%
# Explanation of Mode: ModeResult(mode=np.int64(5), count=np.int64(2))
# mode=np.int64(5)
# → The mode (most frequently occurring value) in your data is 5.

# count=np.int64(2)
# → The value 5 occurs 2 times in the dataset.

# np.int64
# → This just indicates the data type: a NumPy 64-bit integer.
# It behaves the same as a normal Python integer.

# %%
import numpy as np
X = np.array([
    [0, 0],
    [0, 1],
    [1, 0],
    [1, 1]
])
X.shape[0]
# Out:
# 4
